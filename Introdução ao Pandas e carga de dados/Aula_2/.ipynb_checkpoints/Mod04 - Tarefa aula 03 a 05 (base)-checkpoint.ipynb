# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui

pc_mat = df_mat / 24
pc_por = df_por / 18
pc_geo = df_geo /  8
pc_ing = df_ing /  8
pc_his = df_his /  8
pc_fis = df_fis /  8
pc_qui = df_qui /  8

# %%
# 2) Seu código aqui
total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
total
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
total/90
# Out:
#     Qt_acertos
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
# ..         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui
total_gt_45 = total[total['Qt_acertos'] > 45]
total_gt_45.count()
# Out:
# Qt_acertos    31
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
df_eliminados = total[(df_mat['Qt_acertos'] == 0) | 
                      (df_fis['Qt_acertos'] == 0) | 
                      (df_qui['Qt_acertos'] == 0)]

df_eliminados
# Out:
#     Qt_acertos
# 3           32
# 6           29
# 10          31
# 12          42
# 14          31
# 20          53
# 25          27
# 26          40
# 27          50
# 33          39
# 35          48
# 49          19
# 56          39
# 65          24
# 66          31
# 72          50
# 73          37
# 74          39
# 84          26
# 89          63
# 92          40
# 94          25
# 98          40

# %%
# quantidades de alunos desqualificados
qtd_desqualificados = df_eliminados.count()
qtd_desqualificados
# Out:
# Qt_acertos    23
# dtype: int64

# %%
df_eliminados.columns
# Out:
# Index(['Qt_acertos'], dtype='object')

# %%
# Média dos alunos desqualificados em história e geografia (não estou conseguindo fazer)
Média_desqualificados_geo = df_eliminados.loc[(df_geo['Qt_acertos'])
# Out:
#   Cell In[121], line 2
#     Média_desqualificados_geo = df_eliminados.loc[(df_geo['Qt_acertos'])
#                                                                         ^
# SyntaxError: incomplete input

# %%
#Qual a média desses alunos em história e geografia?
geo = df_geo.mean()
print(f'A média em geografia é {geo}.')
hist = df_his.mean()
print(f'A média em história é {hist}.')
# Out:
# A média em geografia é Qt_acertos    3.36
# dtype: float64.
# A média em história é Qt_acertos    3.6
# dtype: float64.

# %%
# alunos não desqualificados com nota de corte acima de 45
df_passou = total[(df_mat['Qt_acertos'] != 0) &
                          (df_fis['Qt_acertos'] != 0) &
                          (df_qui['Qt_acertos'] != 0) &
                          (total['Qt_acertos'] > 45)]
                            
df_passou
# Out:
#     Qt_acertos
# 1           48
# 2           50
# 5           50
# 7           49
# 8           58
# 17          52
# 18          50
# 24          50
# 31          54
# 36          56
# 37          52
# 39          49
# 40          47
# 42          48
# 45          48
# 48          55
# 60          48
# 62          46
# 67          46
# 70          62
# 71          53
# 77          53
# 78          66
# 81          55
# 88          50
# 93          56

# %%
df_passou.count()
# Out:
# Qt_acertos    26
# dtype: int64

# %% [markdown]
# ## Realizei do meu jeito pois não estava conseguindo fazer

# %%
# desta forma não estou conseguindo resolver o exercício 3 do vestibular 2 dito isso vou fazer do meu jeito.(fazendo do meu jeito)
dataframes = [df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui]
df = pd.concat(dataframes, axis =1)
# Out:
# Index(['Qt_acertos', 'Qt_acertos', 'Qt_acertos', 'Qt_acertos', 'Qt_acertos',
#        'Qt_acertos', 'Qt_acertos'],
#       dtype='object')

# %%
#As colunas ficaram todos com os mesmo nomes (fazendo do meu jeito)
colunas = ['Qt_acertos_mat', 'Qt_acertos_por', 'Qt_acertos_geo', 'Qt_acertos_ing', 'Qt_acertos_his',
       'Qt_acertos_fis', 'Qt_acertos_qui']
df.columns = colunas

# %%
#verificando se alterou os nomes das colunas (fazendo do meu jeito)
df.head()
# Out:
#    Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# 0               6               7               7               3
# 1              19              10               0               0
# 2              14              16               0               5
# 3              10               7               3               4
# 4               7               2               2               7
#
#    Qt_acertos_his  Qt_acertos_fis  Qt_acertos_qui
# 0               1               8               3
# 1               0              11               8
# 2               7               4               4
# 3               0               0               8
# 4               0               9               3

# %%
# porcentagem de acerto de cada matéria (fazendo do meu jeito)
df['pc_mat'] = df['Qt_acertos_mat']/ 24
df['pc_por']= df['Qt_acertos_por'] / 18
df['pc_geo'] = df['Qt_acertos_geo'] /  8
df['pc_ing'] = df['Qt_acertos_ing'] /  8
df['pc_his'] = df['Qt_acertos_his'] /  8
df['pc_fis'] = df['Qt_acertos_fis'] /  8
df['pc_qui'] = df['Qt_acertos_qui']/  8

# %%
# verificando (fazendo do meu jeito)
df.head()
# Out:
#    Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# 0               6               7               7               3
# 1              19              10               0               0
# 2              14              16               0               5
# 3              10               7               3               4
# 4               7               2               2               7
#
#    Qt_acertos_his  Qt_acertos_fis  Qt_acertos_qui    pc_mat    pc_por  pc_geo  \
# 0               1               8               3  0.250000  0.388889   0.875
# 1               0              11               8  0.791667  0.555556   0.000
# 2               7               4               4  0.583333  0.888889   0.000
# 3               0               0               8  0.416667  0.388889   0.375
# 4               0               9               3  0.291667  0.111111   0.250
#
#    pc_ing  pc_his  pc_fis  pc_qui
# 0   0.375   0.125   1.000   0.375
# ...

# %%
# criando uma coluna de total e calculando o total (fazendo do meu jeito)
df['total'] =  df['Qt_acertos_mat'] + df['Qt_acertos_por'] + df['Qt_acertos_geo'] + df['Qt_acertos_ing'] + df['Qt_acertos_his'] + df['Qt_acertos_fis'] + df['Qt_acertos_qui']

# %%
# porcentagem geral de cada aluno(a) (fazendo do meu jeito)
df['total']/90
# Out:
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
#         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
# Name: total, Length: 100, dtype: float64

# %%
# total maior que 45 
total_maior_45 = df.loc[df['total'] > 45]
total_maior_45['total'].count()
# Out:
# 31

# %% [markdown]
# # Parte 2

# %%
# alunos que zeraram em matemática, física e química (fazendo do meu jeito)
alunos_eliminados = df[(df['Qt_acertos_mat'] == 0) | 
                       (df['Qt_acertos_fis'] == 0) |
                       (df['Qt_acertos_qui'] == 0)]
alunos_eliminados
# Out:
#     Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# 3               10               7               3               4
# 6                6               0               7               7
# 10              10               8               3               2
# 12              20               8               3               7
# 14               7              11               1               7
# 20              23              11               6               5
# 25               0               4               7               4
# 26              11              14               6               2
# 27              21              13               1               5
# 33              14               8               0               5
# 35              11              14               6               3
# 49               8               1               1               0
# 56               7               6               7               5
# ...

# %%
#média dos alunos em geografia e historia minha invenção (fazendo do meu jeito)
media_historia_eliminado = alunos_eliminados['Qt_acertos_his'].mean()
media_geografia_eliminado = alunos_eliminados['Qt_acertos_geo'].mean()
print(media_historia_eliminado, media_geografia_eliminado)
# Out:
# 3.4347826086956523 3.217391304347826

# %%
#alunos que passaram para segunda fase (fazendo do meu jeito)
alunos_nao_desclassificados = df[(df['Qt_acertos_mat'] != 0) &
                       (df['Qt_acertos_fis'] != 0) &
                       (df['Qt_acertos_qui'] != 0) & (df['total'] > 45)]
alunos_nao_desclassificados
# Out:
#     Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# 1               19              10               0               0
# 2               14              16               0               5
# 5               20               2               5               3
# 7               18               4               4               7
# 8               22               9               2               7
# 17              21              15               2               2
# 18              20               4               3               5
# 24              20               2               7               5
# 31              15              13               3               1
# 36              22               9               6               6
# 37              19              12               5               7
# 39               4              16               2               4
# 40              18               3               6               3
# ...

# %%
#quantidades de alunos para segunda fase (fazendo do meu ejito)
alunos_nao_desclassificados['total'].count()
# Out:
# 26

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? O
# zBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = ''

# %%
# 1) Sua solução aqui
df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')

# %%
df.head()
# Out:
#                                  document_id  \
# 0  b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1  a1acc0b6-1cf6-4c4b-adcb-06b473a0faaf-i0b0
# 2  af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3  4879308e-5050-46bb-b8e2-11fa5646a05c-i0b0
# 4  000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936...              69
# 1  f4e17a9e5354cb45e223d85eda02fb2f76048c801675f5...              81
# 2  6734b26bccf826130ebffa66575977bbe71477b12bcf42...              69
# 3  84a341fd350c1ba7117fccbb4d2df417bc0fac0fffac37...              51
# 4  c59571e19f368d4b0cf08cd3bcabb32e5cd8baad5340f6...              65
#
#   paciente_datanascimento paciente_enumsexobiologico  paciente_racacor_codigo  \
# 0              1951-12-28                          F                        3
# 1              1939-11-22                          M                        3
# ...

# %%
df.shape[0]
# Out:
# 169071

# %%
# 2) 
df['paciente_id'].nunique()
# Out:
# 120517

# %%
# 3) 
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df['paciente_id'].loc[df['vacina_descricao_dose'] == primeira_dose].nunique()
# Out:
# 119713

# %%
# 3) solução alternativa
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df_primeira_dose = df[df['vacina_descricao_dose'] == primeira_dose]
df_primeira_dose['paciente_id'].nunique()
# Out:
# 119713

# %%
# 4) 
df_menor = df[df["paciente_idade"]<18]
df_menor['paciente_id'].nunique()
# Out:
# 47

# %%
# 5)
df['estabelecimento_razaosocial'].nunique()
# Out:
# 42

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) 
df_menor = df[df["paciente_idade"]<18].copy()

# %%
# 2) 
df_menor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_datanascimento', 'paciente_enumsexobiologico',
#        'paciente_racacor_codigo', 'paciente_racacor_valor',
#        'paciente_endereco_coibgemunicipio', 'paciente_endereco_copais',
#        'paciente_endereco_nmmunicipio', 'paciente_endereco_nmpais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumnacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaosocial', 'estalecimento_nofantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoatendimento_codigo',
#        'vacina_grupoatendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataaplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
# ...

# %%
# 3)
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# Povos Indígenas                     33
# Trabalhadores de Saúde               9
# Povos e Comunidades Tradicionais     9
# Comorbidades                         2
# Faixa Etária                         1
# Name: vacina_categoria_nome, dtype: int64

# %%
# 4)
lista_variaveis = ['estabelecimento_valor',
       'estabelecimento_razaosocial', 'estalecimento_nofantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']
df_menor_lista = df_menor.loc[:,lista_variaveis]

# %%
# 5)
df_menor_lista = df_menor_lista.drop_duplicates()
df_menor_lista.shape
# Out:
# (18, 6)
